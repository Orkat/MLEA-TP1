# %%
# %autoreload
import definitions
import data_generation
import plotting

# %%
data = data_generation.generation_functions.generate_simple_pair(100, 0.5)

# %%
plotting.plot_data_functions.plot_data_n_classes(data)
