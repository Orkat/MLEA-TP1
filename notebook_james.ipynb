# %%
# %autoreload
import definitions
import data_generation
import data_plotting

# %%
data = data_generation.generation_functions.generate_simple_pair(1000)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

data_plotting.plot_data_functions.plot_data_n_classes(data)
# Out:
# Populating the interactive namespace from numpy and matplotlib
